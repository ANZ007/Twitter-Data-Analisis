# %%
# !pip install pyLDAvis
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 15.7 MB 34.3 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 34.8 MB/s
# ...
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136897 sha256=d421f05226c40798b2e7158e9bc3b85fbaa46cf938940322451eca5bd585229a
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ...

# %% [markdown]
# ** **
# #### Step 1: Loading Data <a class="anchor\" id="load_data"></a>
# ** **

# %%
import pandas as pd
df1 = pd.read_json (r'/content/beras - scraping.json')
df1.to_csv (r'/content//beras - scraping_convert.csv', index = None)

# %%
# Importing modules
import pandas as pd

# Read data into papers
papers1 = pd.read_csv('/content//beras - scraping_convert.csv')

# Print head
papers1
# Out:
#                                                    url  ...             rating
# 0    https://shopee.co.id/beras-online-beras-idola-...  ...     5 Bintang (44)
# 1    https://shopee.co.id/beras-pera-cap-bung-i.137...  ...      5 Bintang (9)
# 2    https://shopee.co.id/asagri-beras-organik-1-kg...  ...      3 Bintang (4)
# 3    https://shopee.co.id/asagri-beras-merah-organi...  ...  5 Bintang (2,6RB)
# 4    https://shopee.co.id/asagri-beras-merah-organi...  ...    4 Bintang (174)
# ..                                                 ...  ...                ...
# 891  https://shopee.co.id/angola-dispenser-beras-e3...  ...  5 Bintang (2,7RB)
# 892  https://shopee.co.id/angola-dispenser-beras-e3...  ...    4 Bintang (234)
# 893  https://shopee.co.id/angola-dispenser-beras-e3...  ...      2 Bintang (5)
# 894  https://shopee.co.id/angola-dispenser-beras-e3...  ...      2 Bintang (5)
# 895  https://shopee.co.id/angola-dispenser-beras-e3...  ...      1 Bintang (4)
#
# [896 rows x 4 columns]

# %%
papers1=papers1.drop_duplicates(subset=['comment'])
papers1
# Out:
#                                                    url  ...             rating
# 0    https://shopee.co.id/beras-online-beras-idola-...  ...     5 Bintang (44)
# 1    https://shopee.co.id/beras-pera-cap-bung-i.137...  ...      5 Bintang (9)
# 2    https://shopee.co.id/asagri-beras-organik-1-kg...  ...      3 Bintang (4)
# 3    https://shopee.co.id/asagri-beras-merah-organi...  ...  5 Bintang (2,6RB)
# 4    https://shopee.co.id/asagri-beras-merah-organi...  ...    4 Bintang (174)
# ..                                                 ...  ...                ...
# 648  https://shopee.co.id/beras-coklat-organik-sund...  ...      1 Bintang (9)
# 687  https://shopee.co.id/beras-bunga-setra-ramos-s...  ...    5 Bintang (333)
# 778  https://shopee.co.id/beras-slyp-cap-bunga-kemb...  ...    5 Bintang (802)
# 779  https://shopee.co.id/beras-slyp-cap-bunga-kemb...  ...     4 Bintang (26)
# 780  https://shopee.co.id/beras-slyp-cap-bunga-kemb...  ...      2 Bintang (1)
#
# [151 rows x 4 columns]

# %%
import pandas as pd
df2 = pd.read_json (r'/content/beras_merah_1.json')
df2.to_csv (r'/content//beras_merah_1_convert.csv', index = None)

# %%
# Importing modules
import pandas as pd

# Read data into papers
papers2 = pd.read_csv('/content//beras_merah_1_convert.csv')

# Print head
papers2
# Out:
#                                                    url  ...             rating
# 0    https://shopee.co.id/asagri-beras-merah-organi...  ...  5 Bintang (2,6RB)
# 1    https://shopee.co.id/asagri-beras-merah-organi...  ...    4 Bintang (174)
# 2    https://shopee.co.id/asagri-beras-merah-organi...  ...     3 Bintang (17)
# 3    https://shopee.co.id/asagri-beras-merah-organi...  ...      2 Bintang (2)
# 4    https://shopee.co.id/asagri-beras-merah-organi...  ...      2 Bintang (2)
# ..                                                 ...  ...                ...
# 801  https://shopee.co.id/beras-merah-sosoh-1-kg-ki...  ...    5 Bintang (208)
# 802  https://shopee.co.id/beras-merah-fs-1-kg-cocok...  ...     4 Bintang (43)
# 803  https://shopee.co.id/beras-merah-fs-1-kg-cocok...  ...     4 Bintang (43)
# 804  https://shopee.co.id/beras-merah-fs-1-kg-cocok...  ...      3 Bintang (2)
# 805  https://shopee.co.id/beras-merah-fs-1-kg-cocok...  ...      1 Bintang (1)
#
# [806 rows x 4 columns]

# %%
papers2=papers2.drop_duplicates(subset=['comment'])
papers2
# Out:
#                                                    url  ...             rating
# 0    https://shopee.co.id/asagri-beras-merah-organi...  ...  5 Bintang (2,6RB)
# 1    https://shopee.co.id/asagri-beras-merah-organi...  ...    4 Bintang (174)
# 2    https://shopee.co.id/asagri-beras-merah-organi...  ...     3 Bintang (17)
# 3    https://shopee.co.id/asagri-beras-merah-organi...  ...      2 Bintang (2)
# 4    https://shopee.co.id/asagri-beras-merah-organi...  ...      2 Bintang (2)
# ..                                                 ...  ...                ...
# 673  https://shopee.co.id/beras-cap-merek-sumo-5-kg...  ...     4 Bintang (12)
# 784  https://shopee.co.id/beras-merah-sosoh-super-l...  ...  5 Bintang (1,1RB)
# 785  https://shopee.co.id/beras-merah-sosoh-super-l...  ...    4 Bintang (154)
# 786  https://shopee.co.id/beras-merah-sosoh-super-l...  ...     3 Bintang (36)
# 787  https://shopee.co.id/beras-merah-sosoh-super-l...  ...      2 Bintang (9)
#
# [141 rows x 4 columns]

# %%
import pandas as pd
df3 = pd.read_json (r'/content/beras_merah_organik2.json')
df3.to_csv (r'/content//beras_merah_organik2.csv', index = None)

# %%
# Importing modules
import pandas as pd

# Read data into papers
papers3 = pd.read_csv('/content//beras_merah_organik2.csv')

# Print head
papers3
# Out:
#                                                    url  ...             rating
# 0    https://shopee.co.id/asagri-beras-merah-organi...  ...  5 Bintang (2,6RB)
# 1    https://shopee.co.id/asagri-beras-merah-organi...  ...    4 Bintang (176)
# 2    https://shopee.co.id/asagri-beras-merah-organi...  ...     3 Bintang (18)
# 3    https://shopee.co.id/asagri-beras-merah-organi...  ...      2 Bintang (2)
# 4    https://shopee.co.id/asagri-beras-merah-organi...  ...      2 Bintang (2)
# ..                                                 ...  ...                ...
# 757  https://shopee.co.id/beras-merah-organik-langs...  ...    5 Bintang (333)
# 758  https://shopee.co.id/beras-merah-organik-langs...  ...    5 Bintang (333)
# 759  https://shopee.co.id/beras-merah-organik-langs...  ...     4 Bintang (32)
# 760  https://shopee.co.id/beras-merah-organik-langs...  ...      3 Bintang (6)
# 761  https://shopee.co.id/beras-merah-organik-pule-...  ...    5 Bintang (360)
#
# [762 rows x 4 columns]

# %%
import pandas as pd
df3 = pd.read_json (r'/content/beras_organik.json')
df3.to_csv (r'/content//beras_organik.csv', index = None)

# %%
# Importing modules
import pandas as pd

# Read data into papers
papers4 = pd.read_csv('/content//beras_organik.csv')

# Print head
papers4
# Out:
#                                                     url  ...           rating
# 0     https://shopee.co.id/asagri-beras-organik-1-kg...  ...  5 Bintang (770)
# 1     https://shopee.co.id/asagri-beras-organik-1-kg...  ...    3 Bintang (4)
# 2     https://shopee.co.id/halal-mui-bumbu-bunda-by-...  ...  4 Bintang (796)
# 3     https://shopee.co.id/halal-mui-bumbu-bunda-by-...  ...   1 Bintang (16)
# 4     https://shopee.co.id/asagri-beras-mentik-susu-...  ...  5 Bintang (1RB)
# ...                                                 ...  ...              ...
# 1062  https://shopee.co.id/beras-beras-organik-lingk...  ...    4 Bintang (2)
# 1063  https://shopee.co.id/beras-hitam-organik-mama-...  ...   5 Bintang (32)
# 1064  https://shopee.co.id/beras-merah-organik-langs...  ...  5 Bintang (333)
# 1065  https://shopee.co.id/beras-merah-organik-langs...  ...  5 Bintang (333)
# 1066  https://shopee.co.id/beras-merah-organik-langs...  ...   4 Bintang (32)
#
# [1067 rows x 4 columns]

# %%
# Importing modules
import pandas as pd

# Read data into papers
papers = pd.read_csv('/content//data_komentar_beras_shopee.csv')

# Print head
papers
# Out:
#       Unnamed: 0  ...             rating
# 0              0  ...     5 Bintang (44)
# 1              1  ...      5 Bintang (9)
# 2              2  ...      3 Bintang (4)
# 3              3  ...  5 Bintang (2,6RB)
# 4              4  ...    4 Bintang (174)
# ...          ...  ...                ...
# 3526        1062  ...      4 Bintang (2)
# 3527        1063  ...     5 Bintang (32)
# 3528        1064  ...    5 Bintang (333)
# 3529        1065  ...    5 Bintang (333)
# 3530        1066  ...     4 Bintang (32)
#
# [3531 rows x 5 columns]

# %%
papers=papers.drop_duplicates(subset=['comment'])
papers
# Out:
#       Unnamed: 0  ...             rating
# 0              0  ...     5 Bintang (44)
# 1              1  ...      5 Bintang (9)
# 2              2  ...      3 Bintang (4)
# 3              3  ...  5 Bintang (2,6RB)
# 4              4  ...    4 Bintang (174)
# ...          ...  ...                ...
# 3472        1008  ...     4 Bintang (15)
# 3474        1010  ...     5 Bintang (87)
# 3475        1011  ...     4 Bintang (13)
# 3476        1012  ...     4 Bintang (13)
# 3477        1013  ...     5 Bintang (12)
#
# [464 rows x 5 columns]

# %%
# frequency count of column title
count_title = papers1['title'].value_counts()
print(count_title)
# Out:
# Beras Medium Nanasmadu 5 Kg [Gratis Ongkir] - BDG                                                                                                                      7
# Asagri Beras Mentik Susu Organik 1 Kg Solusi MPASI Dan Tambah Nafsu Makan Anak                                                                                         6
# Lingkar Organik Beras Organic 1 Kg Pandan Wangi Putih/Merah/Hitam                                                                                                      6
# beras basmati berasmati asli india 1kg(premium)                                                                                                                        5
# Beras Rojolele Delanggu 10KG                                                                                                                                           5
# ...

# %%
# frequency count of column title
count_title2 = papers2['title'].value_counts()
print(count_title2)
# Out:
# Food Station - Beras Merah 2 pcs @1kg                                                                                                                                  8
# (BISA COD) (FREE B.HITAM) Beras Merah Organik 1 Kg Green 777 1kg Super Premium Quality Sehat Diet Mpasi (VAKUM)                                                        7
# Beras Merah organik/sosoh/kupas/ langsung masak                                                                                                                        6
# Asagri Beras Merah Organik 1 Kg Untuk Diet Rendah Gula dan MPASI Bayi                                                                                                  5
# Beras merah pandanwangi                                                                                                                                                5
# ...

# %%
# frequency count of column rating
papers['ratings'] = papers.rating.apply(lambda x: x[:1])
papers['ratings'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 5    176
# 4    141
# 3     72
# 1     39
# 2     36
# Name: ratings, dtype: int64

# %%
import matplotlib.pyplot as plt
label = ['Rating 4','Rating 5','Rating 3','Rating 1','Rating 2']
plt.pie(papers['ratings'].value_counts(),labels = label)
plt.show()

# %%
# frequency count of column rating
papers1['ratings'] = papers1.rating.apply(lambda x: x[:1])
papers1['ratings'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 4    43
# 5    42
# 3    26
# 1    22
# 2    18
# Name: ratings, dtype: int64

# %%
# frequency count of column rating
papers2['ratings'] = papers2.rating.apply(lambda x: x[:1])
papers2['ratings'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 5    50
# 4    40
# 3    27
# 2    14
# 1    10
# Name: ratings, dtype: int64

# %%
import matplotlib.pyplot as plt
label = ['Rating 4','Rating 5','Rating 3','Rating 1','Rating 2']
plt.pie(papers1['ratings'].value_counts(),labels = label)
plt.show()

# %%
import matplotlib.pyplot as plt
label = ['Rating 4','Rating 5','Rating 3','Rating 1','Rating 2']
plt.pie(papers2['ratings'].value_counts(),labels = label)
plt.show()

# %%
df_product1=papers1["title"]
df_product1= df_product1.drop_duplicates()
df_productTitle1 = pd.DataFrame(df_product1)
df_productTitle1
# Out:
#                                                  title
# 0    Beras Online - Beras Idola 5kg/10kg Beras Pule...
# 1                             Beras Pera Cap Bunga 5KG
# 2    Asagri Beras Organik 1 Kg Premium Pulen Putih ...
# 3    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...
# 8                          Beras Rojolele Delanggu 5KG
# 10   BERAS CAP BUNGA 5LT / 5KG / 10KG / 20KG SETRA ...
# 12                            Beras Raja Platinum 5 Kg
# 15   Beras Raja C4 Segar Jogja 8950/kg (Jogja? Lang...
# 16   (COD) BERAS LOKAL PULEN MURAH 1KG BAHAN MAKANA...
# 18   Beras Sipulen Mutiara Medium Grain 5 Kg [Grati...
# 23   Doonmalai Basmati 1 kg Beras Basmati India Sel...
# 24                                Menir 1kg Beras IR64
# 27   Beras, Pera, Pandan Wangi, Ketan Hitam, Sosoh,...
# 29   BERAS KEPALA SUPER ASLI ROJOLELE 5KG 10KG 20KG...
# 30   Beras SiPulen Long Grain Criystal 5 Kg [Gratis...
# 35                      Beras Karawang Pulen 1Kg Murah
# ...

# %%
df_product2=papers2["title"]
df_product2= df_product2.drop_duplicates()
df_productTitle2 = pd.DataFrame(df_product2)
df_productTitle2
# Out:
#                                                  title
# 0    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...
# 5    Beras Organik 1 Kg / Beras Tanpa Bahan Kimia O...
# 9             Beras Merah untuk diet 1kg Vacum Alkhair
# 12                             Beras merah pandanwangi
# 17   2Kg Beras Merah Organik Premium Super Sidomuly...
# 19   plastik beras c4 raja delanggu 2,5kg dan 3kg b...
# 20   Beras Merah Sosoh, Pulen, Enak, Empuk dan masi...
# 21                                         beras merah
# 22                     Beras Merah Murah Konsumsi 1 Kg
# 23   BERAS MERAH PECAH KULIT CAP BUNGA / KEMBANG 5K...
# 26   BERAS MERAH PANDAN WANGI PULEN ENAK MURAH DIET...
# 27                       BERAS MERAH ORGANIK PULEN 1KG
# 31   LINGKAR ORGANIK 500gr Beras Organic 500gr Bera...
# 34   BERAS MERAH SOSOH 1 KG KILOAN ENAK PULEN TERMU...
# 36   Beras merah FS 1 Kg cocok untuk diet & diabete...
# 40   BERAS MERAH PECAH KULIT ORGANIK - EKA FARM - 1...
# ...

# %%
len(df_productTitle1)
# Out:
# 54

# %%
len(df_productTitle2)
# Out:
# 52

# %% [markdown]
# ** **
# #### Step 2: Data Cleaning <a class="anchor\" id="clean_data"></a>
# ** **

# %%
papers.head()
# Out:
#    Unnamed: 0  ... ratings
# 0           0  ...       5
# 1           1  ...       5
# 2           2  ...       3
# 3           3  ...       5
# 4           4  ...       4
#
# [5 rows x 6 columns]

# %%
# Remove the columns
papers = papers.drop(columns=['url', 'rating', 'Unnamed: 0'], axis=1)
papers = papers[(papers['comment'] != '')]
papers = papers[(papers['comment'].notna())]

# Print out the first rows of papers
papers
# Out:
#                                                   title  ... ratings
# 0     Beras Online - Beras Idola 5kg/10kg Beras Pule...  ...       5
# 1                              Beras Pera Cap Bunga 5KG  ...       5
# 2     Asagri Beras Organik 1 Kg Premium Pulen Putih ...  ...       3
# 3     Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       5
# 4     Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       4
# ...                                                 ...  ...     ...
# 3472  Lingkar Organik Beras Mix Organik (Hitam - Mer...  ...       4
# 3474  BERAS ORGANIK 100GR / BERAS MPASI BAYI / BERAS...  ...       5
# 3475  BERAS ORGANIK 100GR / BERAS MPASI BAYI / BERAS...  ...       4
# 3476  BERAS ORGANIK 100GR / BERAS MPASI BAYI / BERAS...  ...       4
# 3477                  DIVAgro Beras Pandanwangi Organik  ...       5
#
# [463 rows x 3 columns]

# %%
# Remove the columns
papers1 = papers1.drop(columns=['url', 'rating'], axis=1)

# Print out the first rows of papers
papers1
# Out:
#                                                  title  ... ratings
# 0    Beras Online - Beras Idola 5kg/10kg Beras Pule...  ...       5
# 1                             Beras Pera Cap Bunga 5KG  ...       5
# 2    Asagri Beras Organik 1 Kg Premium Pulen Putih ...  ...       3
# 3    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       5
# 4    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       4
# ..                                                 ...  ...     ...
# 648  Beras Coklat Organik - Sundakala - 1kg - Bogor...  ...       1
# 687             Beras Bunga Setra Ramos Slyp Super 5Kg  ...       5
# 778  Beras Slyp Cap Bunga Kembang 15kg & 20kg SUPER...  ...       5
# 779  Beras Slyp Cap Bunga Kembang 15kg & 20kg SUPER...  ...       4
# 780  Beras Slyp Cap Bunga Kembang 15kg & 20kg SUPER...  ...       2
#
# [151 rows x 3 columns]

# %%
# Remove the columns
papers2 = papers2.drop(columns=['url', 'rating'], axis=1)

# Print out the first rows of papers
papers2
# Out:
#                                                  title  ... ratings
# 0    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       5
# 1    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       4
# 2    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       3
# 3    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       2
# 4    Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       2
# ..                                                 ...  ...     ...
# 673  Beras cap merek Sumo 5 kg Asli!!! Kemasan mera...  ...       4
# 784                    Beras Merah Sosoh Super Literan  ...       5
# 785                    Beras Merah Sosoh Super Literan  ...       4
# 786                    Beras Merah Sosoh Super Literan  ...       3
# 787                    Beras Merah Sosoh Super Literan  ...       2
#
# [141 rows x 3 columns]

# %%
papers1.head()
# Out:
#                                                title  ... ratings
# 0  Beras Online - Beras Idola 5kg/10kg Beras Pule...  ...       5
# 1                           Beras Pera Cap Bunga 5KG  ...       5
# 2  Asagri Beras Organik 1 Kg Premium Pulen Putih ...  ...       3
# 3  Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       5
# 4  Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...       4
#
# [5 rows x 3 columns]

# %%
# Load the regular expression library
import re
# Remove punctuation
#df_comment=papers["comment"]
papers['comment_processed'] = papers['comment'].map(lambda x: re.sub("[,\.!?]", "", x))
# Convert the titles to lowercase
papers["comment_processed"] = papers["comment_processed"].map(lambda x: x.lower())
# Print out the first rows of papers
papers["comment_processed"].head()
# Out:
# 0    terimakasih atas paket produknya sudah sampai ...
# 1    bubble wrapnya tebel banget beli ini untuk keb...
# 2    mau beli yg 500gr buat coba2 dulu tapi dikirim...
# 3    rasa: blm tau\nharga: oke\nkualitas: oke\nbaru...
# 4    rasa: blm dicoba\nharga: agak sedikit mahal\nk...
# Name: comment_processed, dtype: object

# %%
# Load the regular expression library
import re
# Remove punctuation
#df_comment=papers["comment"]
papers1['comment_processed'] = papers1['comment'].map(lambda x: re.sub("[,\.!?]", "", x))
# Convert the titles to lowercase
papers1["comment_processed"] = papers1["comment_processed"].map(lambda x: x.lower())
# Print out the first rows of papers
papers1["comment_processed"].head()
# Out:
# 0    terimakasih atas paket produknya sudah sampai ...
# 1    bubble wrapnya tebel banget beli ini untuk keb...
# 2    mau beli yg 500gr buat coba2 dulu tapi dikirim...
# 3    rasa: blm tau\nharga: oke\nkualitas: oke\nbaru...
# 4    rasa: blm dicoba\nharga: agak sedikit mahal\nk...
# Name: comment_processed, dtype: object

# %%
# Load the regular expression library
import re
# Remove punctuation
#df_comment=papers["comment"]
papers2['comment_processed'] = papers2['comment'].map(lambda x: re.sub("[,\.!?]", "", x))
# Convert the titles to lowercase
papers2["comment_processed"] = papers2["comment_processed"].map(lambda x: x.lower())
#Print out the first rows of papers
papers2["comment_processed"].head()
# Out:
# 0    rasa: blm tau\nharga: oke\nkualitas: oke\nbaru...
# 1    rasa: blm dicoba\nharga: agak sedikit mahal\nk...
# 2    pengiriman sih cepat tapi beras nya kurang bag...
# 3    kaget pas buka paket 1 kg tapi kok isinya diki...
# 4                          kualitas produk kurang baik
# Name: comment_processed, dtype: object

# %% [markdown]
# ** **
# #### Step 3: Exploratory Analysis <a class="anchor\" id="eda"></a>
# ** **

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('indonesian')
stop_words.extend(['yg', 'yang', 'gak', 'ga', 'nya', 'yaa', 'tp', 'aja', 'tp', 'unt', 'sih','gtu','gitu','ya','utk','jg','kalo','klo','udh','beras','berasnya'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Import the wordcloud library
from wordcloud import WordCloud

#remove stopword beforehand
papers1['comment_processed'] = papers1['comment_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Join the different processed titles together.
long_string = ','.join(list(papers1['comment_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7EEEF2FE90>

# %%
print(papers1['comment_processed'].str.split(expand=True).stack().value_counts())
# Out:
# harga:          76
# kualitas:       75
# rasa:           75
# pengiriman      48
# bagus           44
#                 ..
# nulis            1
# 😌                1
# berlangganan     1
# thankyouuu       1
# perak            1
# Length: 942, dtype: int64

# %%
print(papers2['comment_processed'].str.split(expand=True).stack().value_counts())
# Out:
# harga:        63
# rasa:         62
# kualitas:     61
# pengiriman    38
# ok            33
#               ..
# bras           1
# khas           1
# trjangka       1
# awet           1
# 🙏🏽             1
# Length: 731, dtype: int64

# %%
rating_bottomTwo = papers1[(papers1['ratings'] == '1') | (papers1['ratings'] == '2')]
rating_bottomTwo.head()
# Out:
#                                                 title  ...                                  comment_processed
# 6   Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...  kaget pas buka paket 1 kg isinya dikit bgt bel...
# 7   Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...                                    kualitas produk
# 14                           Beras Raja Platinum 5 Kg  ...                                           bersemut
# 20  Beras Sipulen Mutiara Medium Grain 5 Kg [Grati...  ...  kualitas: b ajje harga: standart rasa: mayan h...
# 21  Beras Sipulen Mutiara Medium Grain 5 Kg [Grati...  ...  mohon rusak biarpun promo promo gini tusuk tus...
#
# [5 rows x 4 columns]

# %%
# Import the wordcloud library
from wordcloud import WordCloud

#remove stopword beforehand
papers2['comment_processed'] = papers2['comment_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Join the different processed titles together.
long_string = ','.join(list(rating_bottomTwo['comment_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=1, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7EEE56C590>

# %%
rating_3 = papers1[papers1['ratings'] == '3']
rating_3.head()
# Out:
#                                                 title  ...                                  comment_processed
# 2   Asagri Beras Organik 1 Kg Premium Pulen Putih ...  ...  beli 500gr coba2 dikirim 1kg dibayar ribet dik...
# 5   Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...           pengiriman cepat bagus harga 19ribu suka
# 9                         Beras Rojolele Delanggu 5KG  ...    untung bocor nyampe paket plastiknya udah sobek
# 11  BERAS CAP BUNGA 5LT / 5KG / 10KG / 20KG SETRA ...  ...  kualitas batah2 kaya bagus kualitasnya pengiri...
# 19  Beras Sipulen Mutiara Medium Grain 5 Kg [Grati...  ...  rasa: enak harga: terjangkau kualitas: bagus o...
#
# [5 rows x 4 columns]

# %%
# Import the wordcloud library
from wordcloud import WordCloud

#remove stopword beforehand
papers3['comment_processed'] = papers3['comment_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Join the different processed titles together.
long_string = ','.join(list(rating_3['comment_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-af8ad9960107> in <module>()
#       3
#       4 #remove stopword beforehand
# ----> 5 papers3['comment_processed'] = papers3['comment_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
#       6
#       7 # Join the different processed titles together.
#
# NameError: name 'papers3' is not defined

# %%
rating_topTwo = papers1[(papers1['ratings'] == '4') | (papers1['ratings'] == '5')]
rating_topTwo.head()
# Out:
#                                                title  ...                                  comment_processed
# 0  Beras Online - Beras Idola 5kg/10kg Beras Pule...  ...                        terimakasih paket produknya
# 1                           Beras Pera Cap Bunga 5KG  ...  bubble wrapnya tebel banget beli kebutuhan jua...
# 3  Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...  rasa: blm tau harga: oke kualitas: oke nyoba m...
# 4  Asagri Beras Merah Organik 1 Kg Untuk Diet Ren...  ...  rasa: blm dicoba harga: mahal kualitas: blm di...
# 8                        Beras Rojolele Delanggu 5KG  ...  rasa: enak harga: bagus kualitas: bagus pengir...
#
# [5 rows x 4 columns]

# %%
# Import the wordcloud library
from wordcloud import WordCloud

#remove stopword beforehand
papers2['comment_processed'] = papers2['comment_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Join the different processed titles together.
long_string = ','.join(list(rating_topTwo['comment_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7EEE5674D0>

# %% [markdown]
# ** **
# #### Step 4: Prepare text for LDA analysis <a class="anchor\" id="data_preparation"></a>
# ** **

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('indonesian')
stop_words.extend(['yg', 'yang', 'gak', 'ga', 'nya', 'yaa', 'tp', 'aja', 'tp', 'unt', 'sih','gtu','gitu','ya','utk','jg','kalo','klo','udh','beras','berasnya'])

def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]


data = papers1.comment_processed.values.tolist()
data_words = list(sent_to_words(data))

# remove stop words
data_words = remove_stopwords(data_words)

print(data_words[:1][0][:30])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['terimakasih', 'paket', 'produknya']

# %%
import gensim.corpora as corpora

# Create Dictionary
id2word = corpora.Dictionary(data_words)

# Create Corpus
texts = data_words

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1][0][:30])
# Out:
# [(0, 1), (1, 1), (2, 1)]

# %% [markdown]
# ** **
# #### Step 5: LDA model tranining <a class="anchor\" id="train_model"></a>
# ** **

# %%
from pprint import pprint

# number of topics
num_topics = 4

# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)

# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...

# %% [markdown]
# ** **
# #### Step 6: Analyzing our LDA model <a class="anchor\" id="results"></a>
# ** **

# %%
import pyLDAvis
import pyLDAvis.gensim_models
import pickle
import os

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_data_filepath = os.path.join('/content/ldavis_prepared_'+str(num_topics))

# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
if 1 == 1:
    LDAvis_prepared = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(LDAvis_prepared, f)

# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)

pyLDAvis.save_html(LDAvis_prepared, '/content/ldavis_prepared_'+ str(num_topics) +'.html')

LDAvis_prepared
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.049827 -0.049349       1        1  51.281616
# 0     -0.015630  0.016488       2        1  19.327491
# 3      0.073364 -0.023887       3        1  18.116313
# 2     -0.007907  0.056748       4        1  11.274580, topic_info=           Term       Freq      Total Category  logprob  loglift
# 153          ok  19.000000  19.000000  Default  30.0000  30.0000
# 25        harga  70.000000  70.000000  Default  29.0000  29.0000
# 40   pengiriman  36.000000  36.000000  Default  28.0000  28.0000
# 154     pesanan   8.000000   8.000000  Default  27.0000  27.0000
# 27     kualitas  74.000000  74.000000  Default  26.0000  26.0000
# ...

# %%
from gensim.models.coherencemodel import CoherenceModel

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_words, start=2, limit=5, step=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.7/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...

# %%
# Print the coherence scores
for m, cv in zip(model_list, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = LdaModel(num_terms=848, num_topics=2, decay=0.5, chunksize=2000)  has Coherence Value of 0.2755
# Num Topics = LdaModel(num_terms=848, num_topics=3, decay=0.5, chunksize=2000)  has Coherence Value of 0.3136
# Num Topics = LdaModel(num_terms=848, num_topics=4, decay=0.5, chunksize=2000)  has Coherence Value of 0.3272

# %%
# Select the model and print the topics
optimal_model = model_list[0]
model_topics = optimal_model.show_topics(formatted=False)
optimal_model.print_topics(num_words=10)
# Out:
# [(0,
#   '0.042*"kualitas" + 0.033*"harga" + 0.019*"pengiriman" + 0.018*"bagus" + 0.012*"ok" + 0.011*"cepat" + 0.011*"enak" + 0.010*"sesuai" + 0.010*"beli" + 0.010*"seller"'),
#  (1,
#   '0.027*"harga" + 0.018*"kualitas" + 0.012*"lumayan" + 0.012*"pengiriman" + 0.011*"beli" + 0.010*"seller" + 0.010*"semoga" + 0.010*"bagus" + 0.007*"enak" + 0.007*"murah"')]
